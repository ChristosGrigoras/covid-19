# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristosGrigoras/covid-19/blob/main/playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/iMEdD-Lab/open-data/master/COVID-19/greece_cases_v2.csv'
df1 = pd.read_csv(url, error_bad_lines=False)

# %%
df1.head()
# Out:
#   Γεωγραφικό Διαμέρισμα                  Περιφέρεια  ...  2/1/21  2/2/21
# 0                Ελλάδα                      Ελλάδα  ...  2911.0  2946.0
# 1                Αττική                  Άγιον Όρος  ...    11.0    11.0
# 2         Στερεά Ελλάδα  Περιφέρεια Δυτικής Ελλάδας  ...  1215.0  1221.0
# 3          Πελοπόννησος     Περιφέρεια Πελοποννήσου  ...   562.0   568.0
# 4          Πελοπόννησος     Περιφέρεια Πελοποννήσου  ...   450.0   452.0
#
# [5 rows x 348 columns]

# %%
# !pip install libpysal
# !pip install giddy
# Out:
# Requirement already satisfied: libpysal in /usr/local/lib/python3.6/dist-packages (4.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from libpysal) (1.1.5)
# Requirement already satisfied: scipy>=0.11 in /usr/local/lib/python3.6/dist-packages (from libpysal) (1.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from libpysal) (2.11.2)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.6/dist-packages (from libpysal) (1.19.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from libpysal) (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from libpysal) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->libpysal) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->libpysal) (2018.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->libpysal) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->libpysal) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->libpysal) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->libpysal) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->libpysal) (2020.12.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->libpysal) (1.15.0)
# Collecting giddy
#   Downloading https://files.pythonhosted.org/packages/5c/71/f7fc2b41e36b2a06bac30937435d2dedd125f74f3157213ec121ff52d961/giddy-2.3.3-py3-none-any.whl (60kB)
#      |████████████████████████████████| 61kB 3.1MB/s
# Requirement already satisfied: libpysal>=4.0.1 in /usr/local/lib/python3.6/dist-packages (from giddy) (4.4.0)
# Collecting quantecon>=0.4.7
#   Downloading https://files.pythonhosted.org/packages/5d/e3/4fd5f948de917036b5696347b28fa25da7bd7df995e4f9f42db1c3070eb8/quantecon-0.4.8-py3-none-any.whl (230kB)
#      |████████████████████████████████| 235kB 5.5MB/s
# Collecting esda>=2.1.1
#   Downloading https://files.pythonhosted.org/packages/20/02/7c36f3c7c22f048f50ada6402ff3fbe51e0c5365f7d0227196b84d43c82b/esda-2.3.6-py3-none-any.whl (102kB)
#      |████████████████████████████████| 112kB 8.1MB/s
# Collecting mapclassify>=2.1.1
#   Downloading https://files.pythonhosted.org/packages/22/8e/d968c0945d41bb02de0efaa92e31e43a817dc52d30e82b4dfdda407a1903/mapclassify-2.4.2-py3-none-any.whl
# Requirement already satisfied: scipy>=1.3.0 in /usr/local/lib/python3.6/dist-packages (from giddy) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from libpysal>=4.0.1->giddy) (2.23.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from libpysal>=4.0.1->giddy) (2.11.2)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.6/dist-packages (from libpysal>=4.0.1->giddy) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from libpysal>=4.0.1->giddy) (1.1.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from libpysal>=4.0.1->giddy) (4.6.3)
# Requirement already satisfied: numba>=0.38 in /usr/local/lib/python3.6/dist-packages (from quantecon>=0.4.7->giddy) (0.51.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.6/dist-packages (from quantecon>=0.4.7->giddy) (1.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from esda>=2.1.1->giddy) (0.22.2.post1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from mapclassify>=2.1.1->giddy) (2.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->libpysal>=4.0.1->giddy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->libpysal>=4.0.1->giddy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->libpysal>=4.0.1->giddy) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->libpysal>=4.0.1->giddy) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->libpysal>=4.0.1->giddy) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->libpysal>=4.0.1->giddy) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->libpysal>=4.0.1->giddy) (2018.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba>=0.38->quantecon>=0.4.7->giddy) (53.0.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.38->quantecon>=0.4.7->giddy) (0.34.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy->quantecon>=0.4.7->giddy) (1.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->esda>=2.1.1->giddy) (1.0.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->mapclassify>=2.1.1->giddy) (4.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->libpysal>=4.0.1->giddy) (1.15.0)
# Installing collected packages: quantecon, esda, mapclassify, giddy
# Successfully installed esda-2.3.6 giddy-2.3.3 mapclassify-2.4.2 quantecon-0.4.8

# %%
import libpysal 
import numpy as np
from giddy.directional import Rose
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
f = open(libpysal.examples.get_path('spi_download.csv'), 'r')
lines = f.readlines()
f.close()

# %%
lines = [line.strip().split(",") for line in lines]
names = df1.county.to_list()
data = np.array([list(map(int, line[3:])) for line in lines[1:-5]])

# %%
names
out = []
sids  = list(range(len(df1)))
snames = [name for name in names if name not in out]
snames
sids = [names.index(name) for name in snames]

# %%
states = data[sids,:]
us = data[0]
dates = df1.columns[5:]

# %%
data
# Out:
# array([[ 3836,  4084,  4340, ..., 37728, 39430, 40208],
#        [ 2734,  2962,  3206, ..., 31484, 32883, 33768],
#        [ 4769,  5248,  5583, ..., 38898, 41153, 44039],
#        ...,
#        [ 3325,  3599,  3826, ..., 34499, 35892, 36745],
#        [ 3441,  3765,  4053, ..., 36312, 37799, 38275],
#        [ 4412,  4671,  4898, ..., 40481, 42331, 42845]])
